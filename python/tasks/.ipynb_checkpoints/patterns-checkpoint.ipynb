# %%
start,end=1,5
i=start
while(i<=end):
    j=i
    while(j>=start):
        print(j, end=" ")
        j-=1
    print("\n")
    i+=1
# Out:
# 1
#
# 2 1
#
# 3 2 1
#
# 4 3 2 1
#
# 5 4 3 2 1

# %%
# grid x grid
grid,start=11,1
pacePoint=round(grid/2)
print(pacePoint)
#row
row=1
while(row<=grid):
    col=start
    while(col<=grid):
        # print(f"{col} ",end=" ")
        if(row in range(start,pacePoint) and col==start) or (row in range(pacePoint+1,grid+1) and col==grid):
            print(f"* ",end=" ")
        else:
            print(f"   ",end="")
        if(row==pacePoint) or (col==pacePoint):
            print(f"* ",end=" ")
        else:
            print(f"   ",end="")

        if(row)
        
            
        col+=1
    print("\n")
    row+=1
# Out:
# 6
# *                                *
#
# *                                *
#
# *                                *
#
# *                                *
#
# *                                *
#
#    *     *     *     *     *     *     *     *     *     *     *
#
#                                  *                          *
#
#                                  *                          *
#
#                                  *                          *
#
#                                  *                          *
#
#                                  *                          *

# %%
list(range(1,round(11/2)+1))
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
o=round(11/2)
7 in range(1,o+1)
# Out:
# False

# %%
6 in range(2,6)
# Out:
# False

# %%
10 in range(pacePoint,grid+1)
# Out:
# True
