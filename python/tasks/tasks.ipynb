# %%
password=input("Enter Password: ")
isUpper=False
isLower=False
isDigit=False
isSpec=False
if len(password)>=8:
    for i in password:
        # print(i.islower())
        if i.isupper() and isUpper==False:
            isUpper=True
            continue
        if i.islower() and isLower==False:
            isLower=True
            continue
        if i.isdigit() and isDigit==False:
            isDigit=True
            continue
        if not i.isalnum() and isSpec==False:
            isSpec=True
        
    print(isUpper,isLower,isDigit,isSpec)
    if not isUpper: print("There are no Uppercase Chars")
    elif not isLower: print("There are no Lowercase Chars")
    elif not isDigit: print("There are no Digits")
    elif not isSpec: print("There are no Special Chars")
    else: print("Password Validated.")
else:
    print("Error. Password length should be at least 8 Chars Long")

# %%
data = "this Is MY $1000"
result={'lower':0,
        'upper':0,
        'spec-char':0,
        'digits':0,
        'even-number':0,
        'odd-number':0}
for i in data:
    if i.isupper():
        result['upper']+=1
        continue
    if i.islower():
        result['lower']+=1
        continue
    if i.isdigit():
        result['digits']+=1
        if int(i)%2==0:
            result['even-number']+=1
        else:
            result['odd-number']+=1
        continue
    if not i.isalnum():
        result['spec-char']+=1
print(result)
# Out:
# {'lower': 5, 'upper': 3, 'spec-char': 4, 'digits': 4, 'even-number': 3, 'odd-number': 1}

# %%
import math
math.ceil(5.5)
# Out:
# 6

# %%
start,end=1,9
pacePoint=math.ceil(end/2)
f=1
for i in range(start,end+1):
    # print(i,f)
    if i>=pacePoint:
        print(" "*(i-1),"*"*f)
        f-=2
    else:
        print(" "*(end-i),"*"*f)
        f+=2
# Out:
#          *
#         ***
#        *****
#       *******
#      *********
#       *******
#        *****
#         ***
#          *

# %%
start,end=1,9
pacePoint=math.ceil(end/2)
f=1
for i in range(start,end+1):
    # print(i,f)
    print("* "*f)
    if i>=pacePoint:
        f-=2
    else:
        f+=2
# Out:
# *
# * * *
# * * * * *
# * * * * * * *
# * * * * * * * * *
# * * * * * * *
# * * * * *
# * * *
# *

# %%
start,end=1,9
pacePoint=math.ceil(end/2)
f=1
for i in range(start,end+1):
    # print(i,f)
    print("*"*f)
    if i>=pacePoint:
        f-=2
    else:
        f+=2
# Out:
# *
# ***
# *****
# *******
# *********
# *******
# *****
# ***
# *

# %%
teams = [
    "CSK",
    "DC",
    "GT",
    "KKR",
    "LSG",
    "MI",
    "PBKS",
    "RR",
    "RCB",
    "SRH"
]

matches=[f"{i} vs {j}" for i in teams for j in teams if i!=j]

# %%
matches
# Out:
# ['CSK vs DC',
#  'CSK vs GT',
#  'CSK vs KKR',
#  'CSK vs LSG',
#  'CSK vs MI',
#  'CSK vs PBKS',
#  'CSK vs RR',
#  'CSK vs RCB',
#  'CSK vs SRH',
#  'DC vs CSK',
#  'DC vs GT',
#  'DC vs KKR',
#  'DC vs LSG',
#  'DC vs MI',
#  'DC vs PBKS',
#  'DC vs RR',
#  'DC vs RCB',
#  'DC vs SRH',
#  'GT vs CSK',
#  'GT vs DC',
#  'GT vs KKR',
#  'GT vs LSG',
#  'GT vs MI',
#  'GT vs PBKS',
#  'GT vs RR',
#  'GT vs RCB',
#  'GT vs SRH',
#  'KKR vs CSK',
#  'KKR vs DC',
#  'KKR vs GT',
#  'KKR vs LSG',
#  'KKR vs MI',
#  'KKR vs PBKS',
#  'KKR vs RR',
#  'KKR vs RCB',
#  'KKR vs SRH',
#  'LSG vs CSK',
#  'LSG vs DC',
#  'LSG vs GT',
#  'LSG vs KKR',
#  'LSG vs MI',
#  'LSG vs PBKS',
#  'LSG vs RR',
#  'LSG vs RCB',
#  'LSG vs SRH',
#  'MI vs CSK',
#  'MI vs DC',
#  'MI vs GT',
#  'MI vs KKR',
#  'MI vs LSG',
#  'MI vs PBKS',
#  'MI vs RR',
#  'MI vs RCB',
#  'MI vs SRH',
#  'PBKS vs CSK',
#  'PBKS vs DC',
#  'PBKS vs GT',
#  'PBKS vs KKR',
#  'PBKS vs LSG',
#  'PBKS vs MI',
#  'PBKS vs RR',
# ...

# %%
len(matches)
# Out:
# 90
