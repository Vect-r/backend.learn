# %%
import re

data = "frdsfdsfbgvrt brijesh@gmail.com retwfwet 2-01/2025 MoBilE +91 9898987633 ,yut jhugftiokf kuyhgofdillf ju brijesh.gondaliya@gmail.com ,jhtjskd ;   liedf oijh;oijfwe Mobile : 8980145007 koyd jh kj; mn;u whguul;  04/12/2025 ,ujhyfgoikufd uiph;if n brijesh-gondaliya@yahoo.in.co koyguhfd ;lkj ioj ds 23-0-2022 .,k uyik jhgl; mobile : 898-0145-007 "

# %%
ycl="Cyclone dyclone was hit near indian ocean"

re.findall('[A-Za-z]yclone',ycl)
# Out:
# ['Cyclone', 'dyclone']

# %%
re.findall(r'[a-z]*@[a-z]*.*',"my email xyz@abc.com")
# Out:
# ['xyz@']

# %%
re.findall(r'[a-z0-9+_.-]*@[a-z.-]*',data)
# Out:
# ['brijesh@gmail.com',
#  'brijesh.gondaliya@gmail.com',
#  'brijesh-gondaliya@yahoo.in.co']

# %%
print(re.findall(r'[0-9][0-9]/[0-9][1-2]/\d{4}',data))
print(re.findall(r'[0-9][0-9]-[0-9][1-2]-\d{4}',data))
# Out:
# ['04/12/2025']
# []

# %%
re.findall(r'\b\d{2} \d{10}',data)
# Out:
# ['91 9898987633']

# %%
print(re.findall(r'\+\d{2,3} \d{10}',data))
print(re.findall(r'\d{10}',data))
# Out:
# ['+91 9898987633']
# ['9898987633', '8980145007']
